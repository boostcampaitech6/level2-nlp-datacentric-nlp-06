# %% [markdown]
# # back translation

# %%
import sys
print(sys.executable)
# Out:
# /opt/conda/envs/pororo/bin/python

# %%
import torch
torch.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-414144362cc5> in <module>()
# ----> 1 import torch
#       2 torch.__version__
#
# ModuleNotFoundError: No module named 'torch'

# %%
from pororo import Pororo
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /opt/conda/lib/python3.8/site-packages/transformers/utils/import_utils.py:1110, in _LazyModule._get_module(self, module_name)
#    1109 try:
# -> 1110     return importlib.import_module("." + module_name, self.__name__)
#    1111 except Exception as e:
#
# File /opt/conda/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# ...

# %% [markdown]
# pororo는 torch 1.6버전만 사용 가능

# %%
mt = Pororo(task="translation", lang="multi")

# %%
# 번역할 문장 대입
mt("케빈은 아직도 일을 하고 있다.", src="ko", tgt="en")
